# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem A

# %%
def inverse_distribution(n, given_lambda):
    return - np.log(1.0 - n) / given_lambda

# %%
def generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d):
    n = np.random.uniform(0, 1, N)
    c_t = inverse_distribution(n, lambda_a)
    q_t = inverse_distribution(n, lambda_d)
    return c_t, q_t

# %%
class LabeledObject:
    label = "label"
    val = 0.0
    def __init__(self, label, val):
        self.val = val
        self.label = label

# %%
def generate_arrival_and_delivery_times(N, c_t, q_t):
    A = [c_t[0]] 
    for i in range(1, N):
        A = np.append(A, A[i-1] + c_t[i])
    D = [c_t[0]+q_t[0]] 
    for i in range(1, N):
        D = np.append(D, max(D[i - 1], A[i]) + q_t[i])
    return A, D

# %%
def generate_queue(AD):
    AD.sort(key=lambda x: x.val)
    queue = [0]
    counter=0
    ax = []
    for ad in AD:
        if ad.label == "A":
            queue.append(queue[-1] + 1)
            ax.append(counter)
        else:
            queue.append(queue[-1] - 1)
            counter+=1
    return queue, ax

# %%
N = 10
lambda_a = 2.0
lambda_d = 2.5

c_t, q_t = generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d)
A, D = generate_arrival_and_delivery_times(N, c_t, q_t)
A_mapped = list(map(lambda a: LabeledObject("A", a), A))
D_mapped = list(map(lambda d: LabeledObject("D", d), D))
AD = A_mapped + D_mapped
queue, ax = generate_queue(AD)

print(ax)

time = np.linspace(1, N, N)

print(A)
print(D)
scale_A = [100 * i for i in c_t]
scale_D = [100 * i for i in q_t]

plt.scatter(A, ax, label='Arriving tasks')
plt.scatter(D, range(1,len(D)+1), s=scale_D, label='Completed tasks')
plt.legend()
plt.show()
print()

plt.plot([0] + list(map(lambda a: a.val, AD)), queue, 'o', label='Queue')
plt.legend()
plt.show()
# Out:
# [0, 1, 2, 2, 2, 3, 3, 4, 5, 9]
# [0.278955   0.96457837 1.67704162 1.93271668 2.06355773 2.28216529
#  2.39856468 2.53373719 2.56959038 4.34822866]
# [0.502119   1.51307706 2.24701221 2.45155227 2.5562251  2.73111116
#  2.82423066 2.93236867 2.96105123 5.77113927]

# %%
N = 10
lambda_a = 2.0
lambda_d = 1.5

c_t, q_t = generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d)
A, D = generate_arrival_and_delivery_times(N, c_t, q_t)
A_mapped = list(map(lambda a: LabeledObject("A", a), A))
D_mapped = list(map(lambda d: LabeledObject("D", d), D))
AD = A_mapped + D_mapped
queue, ax = generate_queue(AD)

print(ax)

time = np.linspace(1, N, N)

print(A)
print(D)
scale_A = [100 * i for i in c_t]
scale_D = [100 * i for i in q_t]

plt.scatter(A, ax, label='Arriving tasks')
plt.scatter(D, range(1,len(D)+1), s=scale_D, label='Completed tasks')
plt.legend()
plt.show()
print()

plt.plot([0] + list(map(lambda a: a.val, AD)), queue, 'o', label='Queue')
plt.legend()
plt.show()
# Out:
# [0, 0, 0, 2, 3, 3, 3, 3, 3, 3]
# [1.77195087 1.89437545 2.47510894 4.35762346 5.22399575 5.44186627
#  5.62510513 6.11983675 6.75961605 6.86991318]
# [ 4.13455204  4.29778481  5.07209612  7.58211549  8.73727854  9.02777256
#   9.27209104  9.93173321 10.78477228 10.93183511]

# %% [markdown]
# # Problem B

# %%
N = 10000
lambda_a = 2.0
lambda_d = 3.0

c_t, q_t = generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d)
A, D = generate_arrival_and_delivery_times(N, c_t, q_t)
A_mapped = list(map(lambda a: LabeledObject("A", a), A))
D_mapped = list(map(lambda d: LabeledObject("D", d), D))
AD = A_mapped + D_mapped
queue, ax = generate_queue(AD)

en_sum = 0
t_sum = 0
for q, ad in zip(queue, AD):
    en_sum += q*ad.val
    t_sum+=ad.val

print(en_sum/t_sum)

Experimental_En = np.mean(queue)
print(Experimental_En)

er_sum = 0
for a, d in zip(A,D):
    er_sum += d-a

print(lambda_a*er_sum/N)
# Out:
# 1.8300227425174187
# 1.8115094245287735
# 1.3317204398976155

# %%
N = 10000
lambda_a = 2.0
lambda_d = 5.0

c_t, q_t = generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d)
A, D = generate_arrival_and_delivery_times(N, c_t, q_t)
A_mapped = list(map(lambda a: LabeledObject("A", a), A))
D_mapped = list(map(lambda d: LabeledObject("D", d), D))
AD = A_mapped + D_mapped
queue, ax = generate_queue(AD)

en_sum = 0
t_sum = 0
for q, ad in zip(queue, AD):
    en_sum += q*ad.val
    t_sum+=ad.val

print(en_sum/t_sum)

Experimental_En = np.mean(queue)
print(Experimental_En)

er_sum = 0
for a, d in zip(A,D):
    er_sum += d-a

print(lambda_a*er_sum/N)
# Out:
# 1.0761708129807295
# 1.0768461576921153
# 0.5750391084339378

# %% [markdown]
# # Problem C

# %%
N = 1000
lambda_a = 15.0
lambda_d = 8.0

c_t, q_t = generate_enqueue_and_completition_intervals(N, lambda_a, lambda_d)
A, D = generate_arrival_and_delivery_times(N, c_t, q_t)
A_mapped = list(map(lambda a: LabeledObject("A", a), A))
D_mapped = list(map(lambda d: LabeledObject("D", d), D))
AD = A_mapped + D_mapped
queue, ax = generate_queue(AD)

time = np.linspace(1, N, N)

scale_A = [100 * i for i in c_t]
scale_D = [100 * i for i in q_t]

plt.scatter(A, ax, label='Arriving tasks')
plt.scatter(D, range(1,len(D)+1), s=scale_D, label='Completed tasks')
plt.legend()
plt.show()

plt.plot([0] + list(map(lambda a: a.val, AD)), queue, 'o', label='Queue')
plt.legend()
plt.show()

# %%
arriving_tasks = [value * (lambda_a-lambda_d) for value in D]
completed_tasks = [value * (lambda_a-lambda_d)/lambda_d for value in A]
plt.plot(D,arriving_tasks)
plt.plot(A,completed_tasks)
